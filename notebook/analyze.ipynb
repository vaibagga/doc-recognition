# %%
## LOADING
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
X = np.load("../data/midv500_np/train_image0.npy")
y = np.load("../data/midv500_np/mask_image0.npy")

# %%
idx = random.randint(0,X.shape[0])
print(X[idx,:].shape, y[idx,:].shape)
# Out:
# (256, 256, 3) (256, 256, 1)

# %%
plt.imshow(X[idx,:])

# %%
plt.imshow(y[idx,:])

# %%
plt.imshow((y[idx,:] > 1).astype(int))

# %%
np.unique(y[idx,:].astype(bool).astype(int))
# Out:
# array([0, 1])
